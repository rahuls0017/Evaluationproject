# %% [markdown]
# ## Evaluation Project --> Corona Dataset

# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings("ignore")

# %%
#loading the dataset
ds = pd.read_csv("corona19.csv")
ds
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-21 02:32:54  32.3182
# 1                     Alaska             US  2020-05-21 02:32:54  61.3707
# 2             American Samoa             US  2020-05-21 02:32:54 -14.2710
# 3                    Arizona             US  2020-05-21 02:32:54  33.7298
# 4                   Arkansas             US  2020-05-21 02:32:54  34.9697
# 5                 California             US  2020-05-21 02:32:54  36.1162
# 6                   Colorado             US  2020-05-21 02:32:54  39.0598
# 7                Connecticut             US  2020-05-21 02:32:54  41.5978
# 8                   Delaware             US  2020-05-21 02:32:54  39.3185
# 9           Diamond Princess             US  2020-05-21 02:32:54      NaN
# 10      District of Columbia             US  2020-05-21 02:32:54  38.8974
# 11                   Florida             US  2020-05-21 02:32:54  27.7663
# ...

# %%
#lets see the first five rows of dataset
ds.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-05-21 02:32:54  32.3182  -86.9023
# 1          Alaska             US  2020-05-21 02:32:54  61.3707 -152.4044
# 2  American Samoa             US  2020-05-21 02:32:54 -14.2710 -170.1320
# 3         Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 4        Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      13052     522        NaN  12530.0     1     266.194321       164450.0
# 1        401      10      352.0     39.0     2      54.815493        37045.0
# 2          0       0        NaN      0.0    60       0.000000          124.0
# 3      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 4       5003     107     3852.0   1044.0     5     165.782801        96258.0
#
# ...

# %%
#lets see the last 5 rows of dataset
ds.tail()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 53       Virginia             US  2020-05-21 02:32:54  37.7693  -78.1700
# 54     Washington             US  2020-05-21 02:32:54  47.4009 -121.4905
# 55  West Virginia             US  2020-05-21 02:32:54  38.4912  -80.9545
# 56      Wisconsin             US  2020-05-21 02:32:54  44.2685  -89.6165
# 57        Wyoming             US  2020-05-21 02:32:54  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 53      32908    1075     4523.0  27310.0    51     385.541875       212626.0
# 54      18971    1037        NaN  17934.0    53     249.130224       293120.0
# 55       1567      69      950.0    548.0    54      87.437024        80641.0
# 56      13413     481     7728.0   5204.0    55     230.367575       167713.0
# 57        787      11      528.0    248.0    56     135.980607        18840.0
#
# ...

# %%
#lets see random sample of dataset
ds.sample()
# Out:
#    Province_State Country_Region          Last_Update      Lat    Long_  \
# 43   Pennsylvania             US  2020-05-21 02:32:54  40.5908 -77.2098
#
#     Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 43      68126    4770        NaN  63356.0    42     532.151684       349700.0
#
#     People_Hospitalized  Mortality_Rate       UID ISO3  Testing_Rate  \
# 43                  NaN        7.001732  84000042  USA   2731.606784
#
#     Hospitalization_Rate
# 43                   NaN

# %%
#check the shape of dataset
ds.shape
# Out:
# (58, 18)

# %%
#information of the dataset
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %% [markdown]
# #there are 4 categorical columns and 14 numeric columns.

# %%
#datatypes of the dataset
ds.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %% [markdown]
# #there are 10 columns with float dtypes,4 columns with int dtype,4 columns with object dtype.

# %%
#checking the null values of the dataset
ds.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %% [markdown]
# #There are some missing values. so we will have to fill them.

# %%
#checking null values using heatmap
sns.heatmap(ds.isnull())

# %%
#columns 'Country_region','Last_update','Uid','ISO3' can be dropped from dataset as they are not helpful for analysing.
ds.drop(columns=['Province_State','Country_Region','Last_Update','UID','ISO3'],inplace = True)

# %%
#statistical summary
ds.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  56.000000   56.000000      58.000000     58.000000     42.000000
# mean   36.840089  -85.206614   26756.086207   1611.017241   7007.428571
# std    10.887035   49.754449   52562.031122   4084.750891  11674.490020
# min   -14.271000 -170.132000       0.000000      0.000000     13.000000
# 25%    34.594600 -101.165775    2596.000000     74.000000    970.000000
# 50%    39.061850  -87.944200   10148.500000    385.000000   3008.000000
# 75%    42.361650  -76.970625   29395.500000   1394.250000   7326.750000
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count      58.000000     58.000000      56.000000   5.600000e+01
# mean    20070.724138   3288.086207     396.230806   2.258534e+05
# std     41294.705318  17408.350591     402.682539   2.987834e+05
# ...

# %% [markdown]
# #observations
# 1. in the columns 'FIPS','active','recovered','Deaths','Confirmed','incident','People_hospitalized','TestingRate','HospitalizationRate' the Mean values are greater than median values.
# 2. there is large difference between 75% and max values of columns 'Confirmed','Deaths','FIPS','active','recovered','incident','People_hospitalized','TestingRate'. so, outliers can be present.

# %%
#filling the null values
ds = ds.apply(pd.to_numeric)
ds['Lat']=ds.fillna(ds['Lat'].mean())
ds['Long_']=ds.fillna(ds['Long_'].mean())
ds['Recovered']=ds.fillna(ds['Recovered'].mean())
ds['People_Hospitalized']=ds.fillna(ds['People_Hospitalized'].mean())
ds['Testing_Rate']=ds.fillna(ds['Testing_Rate'].mean())
ds['Hospitalization_Rate']=ds.fillna(ds['Hospitalization_Rate'].mean())
ds['Incident_Rate']=ds.fillna(ds['Incident_Rate'].mean())
ds['People_Tested']=ds.fillna(ds['People_Tested'].mean())
ds['Mortality_Rate']=ds.fillna(ds['Mortality_Rate'].mean())

# %%
#checking the null values again
ds.isnull().sum()
# Out:
# Lat                     0
# Long_                   0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %%
ds.dtypes
# Out:
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %%
#checking the correlation
dscorr = ds.corr()
plt.figure(figsize=(15,8))
sns.heatmap(dscorr,annot=True,linewidths = 0.5)

# %% [raw]
# #observations:
# #1."confirmed","Active" columns are strongly correlated with "Deaths" columns.
# #2. "lat","Long","Recovered","Incident_rate","People_Tested","People_Hospitalized","mortality_Rate","Testing_Rate","hospitalization_Rate" columns weakly correlated with "Deaths" column.
# #3."FIPS" column is negetive weakly correlated with "Death' column

# %%
#plot the scatterplot
sns.scatterplot(x= 'Confirmed', y = 'Deaths', data = ds)

# %% [markdown]
# #the plot shows as the confirmed cases increases the death increases.

# %%
sns.scatterplot(x= 'Active', y = 'Deaths', data = ds)

# %% [markdown]
# #the plot shows as the active cases increases the death increases.

# %%
sns.scatterplot(x='Confirmed',y='Recovered',data=ds)

# %% [markdown]
# #the plot shows confirmed cases are between 0 and 50000 and recovered are between 30 and 50.

# %%
sns.scatterplot(x='People_Tested',y='Deaths',data=ds)

# %% [markdown]
# #the plot shows the people tested were between 30 and 50 and deaths between 0 and 5000.

# %%
sns.scatterplot(x='Testing_Rate',y='Mortality_Rate',data=ds)

# %% [markdown]
# #the plot shows as the testing rate increases mortality rate increases.

# %%
#checking for outliers
from scipy.stats import zscore
import numpy as np
z = np.abs(zscore(ds))
threshold = 3
new_ds = ds[(z<3).all(axis=1)]

# %%
print(ds.shape)
print(new_ds.shape)
# Out:
# (58, 13)
# (54, 13)

# %%
p_loss = (4/58)*100
p_loss
# Out:
# 6.896551724137931

# %% [markdown]
# #as the p_loss is less. we can remove the outliers.

# %%
ds.skew()
# Out:
# Lat                    -2.250097
# Long_                  -2.250097
# Confirmed               4.708614
# Deaths                  5.489201
# Recovered              -2.250097
# Active                  4.180953
# FIPS                    5.269070
# Incident_Rate          -2.250097
# People_Tested          -2.250097
# People_Hospitalized    -2.250097
# Mortality_Rate         -2.250097
# Testing_Rate           -2.250097
# Hospitalization_Rate   -2.250097
# dtype: float64

# %% [markdown]
# #as the skewness is present in all columns. we have to remove it.

# %% [markdown]
# ##### Preparing dataset for model

# %%
x=new_ds.drop('Deaths',axis=1)
y=new_ds['Deaths']

# %%
#removing skewness
from sklearn.preprocessing import power_transform
x = power_transform(x, method = 'yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %% [markdown]
# ##### finding the best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def max_r2_score(clf,x,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
        
        clf.fit(x_train,y_train)
        y_pred = clf.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print(clf,"max r2 score corresponding to ",final_r_state," is ",max_r_score)

# %% [markdown]
# ##### finding the best model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
model=[LinearRegression(),DecisionTreeRegressor(),RandomForestRegressor(),KNeighborsRegressor()]
for m in model:
    max_r2_score(m,x,y)
# Out:
# LinearRegression() max r2 score corresponding to  46  is  0.8501659154806289
# DecisionTreeRegressor() max r2 score corresponding to  63  is  0.9459004264101716
# RandomForestRegressor() max r2 score corresponding to  63  is  0.9522781361139266
# KNeighborsRegressor() max r2 score corresponding to  63  is  0.973705782562437

# %% [markdown]
# ##### ensemble Technique

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 54,test_size=0.20)
rfr.fit(x_train, y_train)
y_pred = rfr.predict(x_test)
print('r2_score',r2_score(y_train, rfr.predict(x_train)))
rfr_accuracy = round(rfr.score(x_train,y_train),2)
print('rfr_accuracy:',rfr_accuracy)
# Out:
# r2_score 0.9489411219864933
# rfr_accuracy: 0.95

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(x_train,y_train)
y_pred = gbr.predict(x_test)
print('r2_score',r2_score(y_train,gbr.predict(x_train)))
gbr_accuracy = round(gbr.score(x_train,y_train),2)
print('gbr accuracy: ',gbr_accuracy)
# Out:
# r2_score 0.9999540742820472
# gbr accuracy:  1.0

# %% [markdown]
# ##### Cross val score

# %%
from sklearn.model_selection import cross_val_score
cv_score = cross_val_score(gbr, x_train, y_train, cv=5, scoring='r2')
print(np.sqrt(np.abs(cv_score)))
# Out:
# [0.83533874 0.78439176 0.57108081 0.35573696 0.76996623]

# %%
from sklearn.model_selection import cross_val_score
knn = KNeighborsRegressor()
cv_score = cross_val_score(knn, x_train, y_train, cv=5, scoring='r2')
print(np.sqrt(np.abs(cv_score)))
# Out:
# [0.94665885 0.74307391 1.93879008 0.91976332 0.63846746]

# %% [markdown]
# ###### Hypertune Parameter

# %%
from sklearn.model_selection import GridSearchCV
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
gbr = GradientBoostingRegressor()
clf = GridSearchCV(gbr, parameters, cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 10}

# %%
gbr = GradientBoostingRegressor(learning_rate =0.1,n_estimators=10)
gbr.fit(x_train,y_train)
y_pred = gbr.predict(x_test)
print('r2_score',r2_score(y_train,gbr.predict(x_train)))
gbr_accuracy = round(gbr.score(x_train,y_train),2)
print('gbr accuracy: ',gbr_accuracy)
# Out:
# r2_score 0.8687561629317496
# gbr accuracy:  0.87

# %%
knn=KNeighborsRegressor()
neighbors={"n_neighbors":range(1,30)}
clf = GridSearchCV(knn, neighbors, cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'n_neighbors': 6}

# %%
knn = KNeighborsRegressor(n_neighbors = 6)
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)
print('r2_score',r2_score(y_train,knn.predict(x_train)))
knn_accuracy = round(knn.score(x_train,y_train),2)
print('KNN accuracy: ',knn_accuracy)
# Out:
# r2_score 0.7779765977960955
# KNN accuracy:  0.78

# %%
#we can choose Gradient Boosting Regressor as our best model

# %% [markdown]
# ##### Saving the model

# %%
from joblib import dump, load
dump(gbr, 'covid_19.joblib')
# Out:
# ['covid_19.joblib']
