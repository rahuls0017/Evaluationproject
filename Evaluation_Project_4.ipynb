# %% [markdown]
# ## Evaluation Project 4 HR Analytics

# %%
#Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %%
#loading the dataset
rs = pd.read_csv("HR_Employee_Attrition.csv")
rs
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
#to get the first five rows of dataset
rs.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#to get the last 5 rows of dataset
rs.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
#to get the random sample of the dataset 
rs.sample()
# Out:
#      Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 423   30        No     Non-Travel       1398      Sales                22
#
#      Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 423          4          Other              1             567  ...
#
#      RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 423                         3            80                 0
#
#      TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 423                 10                      3               3               9
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 423                  8                        7                     8
#
# [1 rows x 35 columns]

# %%
#to get the inforamtion of the dataset
rs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#to get the datatypes of the dataset
rs.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
#  there are 9 columns of object datatypes and 26 columns of int types

# %%
#there is a column "EmployeeNumber" in the dataset which is not usefull so we can drop it.
rs.drop("EmployeeNumber", axis =1, inplace = True)

# %%
#to get dimension of the dataset
rs.shape
# Out:
# (1470, 34)

# %%
#to check if any null values are present in the dataset
rs.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
# to check the null values graphically
sns.heatmap(rs.isnull())

# %% [markdown]
# #the dataset has no null values

# %%
#statistical summary
rs.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# ...

# %% [markdown]
# #there is no missing value in the data
# #in age,dailyrate,distancefromhome columns the mean value is greater than median values.
# #in standard hours,employeecount columns all the values are equal to 80 and 1.0. so it is not providing any info
# #so we can drop them.

# %%
#dropping the two columns
rs.drop(columns=["EmployeeCount","StandardHours"],axis =1,inplace = True)

# %%
#again checking the dimension of dataset
rs.shape
# Out:
# (1470, 32)

# %%
#plotting the counts of attrition 
sns.countplot("Attrition",data = rs)
plt.show()

# %% [markdown]
# #it show that company is facing less attrition

# %%
rs["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
#plot to check how does the employee travels
sns.countplot("BusinessTravel",data = rs)
plt.show()

# %%
print(rs['BusinessTravel'].unique())
# Out:
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']

# %%
print(rs['BusinessTravel'].value_counts())
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# #from the graph and counts we can say that there are more employees which travel rarely.

# %%
#plot to see the count of attrition with respect to buisness travel.
sns.countplot(x="BusinessTravel",hue="Attrition",data = rs)
plt.show()

# %%
rs.groupby(['BusinessTravel'])['Attrition'].value_counts()
# Out:
# BusinessTravel     Attrition
# Non-Travel         No           138
#                    Yes           12
# Travel_Frequently  No           208
#                    Yes           69
# Travel_Rarely      No           887
#                    Yes          156
# Name: Attrition, dtype: int64

# %% [markdown]
# #based on the plot we can say that proportion of attrition is more where employees travel frequently.

# %%
#plot the graph of attrition with respect to age
sns.barplot(x="Attrition",y="Age",data=rs)
plt.show()

# %% [markdown]
# #the plot shows that employees who are not leaving has more value.

# %%
#plot of attrintion with respect to department
sns.countplot(x="Department",hue="Attrition", data = rs)
plt.show()

# %%
rs.groupby(['Department'])['Attrition'].value_counts()
# Out:
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# Name: Attrition, dtype: int64

# %%
#we can conclude that attrition rate is 1:4 in HR,1:8 in R&D,1:4 in sales.

# %%
#plot of attrition wrt jobrole
plt.figure(figsize=(30,5))
sns.countplot(x="JobRole",hue="Attrition",data =rs)
plt.show()

# %%
rs.groupby(["JobRole"])['Attrition'].value_counts()
# Out:
# JobRole                    Attrition
# Healthcare Representative  No           122
#                            Yes            9
# Human Resources            No            40
#                            Yes           12
# Laboratory Technician      No           197
#                            Yes           62
# Manager                    No            97
#                            Yes            5
# Manufacturing Director     No           135
#                            Yes           10
# Research Director          No            78
#                            Yes            2
# Research Scientist         No           245
#                            Yes           47
# Sales Executive            No           269
#                            Yes           57
# Sales Representative       No            50
#                            Yes           33
# Name: Attrition, dtype: int64

# %%
#from here we can see attrition rate is higher in "Laboratory Technician" and low in"Reserach Director".

# %%
#plot of Attrition wrt Educationfield
plt.figure(figsize=(30,5))
sns.countplot(x="EducationField",hue="Attrition",data =rs)
plt.show()

# %%
#plot of attrition wrt Education
plt.figure(figsize=(30,5))
sns.countplot(x="Education",hue="Attrition",data =rs)
plt.show()

# %%
#plotting attrition based on job satisfaction
sns.countplot(x="JobSatisfaction",hue="Attrition",data=rs)
plt.show()
#here we are able  to see that as job satisfaction increases proportion of aleavers decreases

# %%
#plot attrition with respect to gender
sns.countplot(x="Gender",hue="Attrition",data =rs)
plt.show()

# %%
#plot the attrition wrt MaritalStatus
sns.countplot(x="MaritalStatus",hue="Attrition",data =rs)
plt.show()
#in singles ratio is higher

# %%
#plot to check attrition based on overtime.
sns.countplot(x="OverTime",hue="Attrition",data =rs)
plt.show()
#Below if graph clearly shows if overtime is there then attrition proportion is higher

# %%
# plot of attrition wrt yesra at company
plt.figure(figsize=(30,5))
sns.countplot(hue="Attrition",x="YearsAtCompany",data=rs)
plt.show()
# so here we get what is the average number of years employee is staying in the company before leaving

# %%
rs.groupby(['YearsAtCompany'])['Attrition'].value_counts()
# Out:
# YearsAtCompany  Attrition
# 0               No            28
#                 Yes           16
# 1               No           112
#                 Yes           59
# 2               No           100
#                             ...
# 33              Yes            1
# 34              No             1
# 36              No             2
# 37              No             1
# 40              Yes            1
# Name: Attrition, Length: 64, dtype: int64

# %%
#we can conclude that attrition rate is higher upto 5 years.

# %%
#check the attrition wrt to Years with current manager
rs.groupby(['YearsWithCurrManager'])['Attrition'].value_counts()
# Out:
# YearsWithCurrManager  Attrition
# 0                     No           178
#                       Yes           85
# 1                     No            65
#                       Yes           11
# 2                     No           294
#                       Yes           50
# 3                     No           123
#                       Yes           19
# 4                     No            87
#                       Yes           11
# 5                     No            27
#                       Yes            4
# 6                     No            25
#                       Yes            4
# 7                     No           185
#                       Yes           31
# 8                     No            97
#                       Yes           10
# 9                     No            58
#                       Yes            6
# 10                    No            24
#                       Yes            3
# 11                    No            21
# ...

# %% [markdown]
# #we can say that at starting only many employees left.

# %%
#plot to check the work life balance wrt attrition
sns.countplot(x="WorkLifeBalance",data=rs,hue = "Attrition")
plt.show()

# %%
#plot for performance rating wrt attrition
sns.countplot(x = 'PerformanceRating',hue="Attrition",data=rs)
plt.show()

# %% [markdown]
# #employees with rating 3 has higher attrition rate compare to rating4.

# %%
#check the attrition wrt years since  last promotion 
rs.groupby(["YearsSinceLastPromotion"])["Attrition"].value_counts()
# Out:
# YearsSinceLastPromotion  Attrition
# 0                        No           471
#                          Yes          110
# 1                        No           308
#                          Yes           49
# 2                        No           132
#                          Yes           27
# 3                        No            43
#                          Yes            9
# 4                        No            56
#                          Yes            5
# 5                        No            43
#                          Yes            2
# 6                        No            26
#                          Yes            6
# 7                        No            60
#                          Yes           16
# 8                        No            18
# 9                        No            13
#                          Yes            4
# 10                       No             5
#                          Yes            1
# ...

# %% [markdown]
# ##we can say that more people left before single year passed since last promotion

# %%
#check attrition wrt PercentSalaryHike
sns.countplot(x='PercentSalaryHike',hue='Attrition',data =rs)
plt.show()

# %% [markdown]
# #employee with less percent salray hike, attrition rate is more

# %%
#plot for attrition wrt totalworkinghours
plt.figure(figsize=(30,5))
sns.countplot(x='TotalWorkingYears',hue='Attrition',data =rs)
plt.show()

# %% [markdown]
# #employees with less total Working Years Attrition rate is more.

# %%
#plot for attrition wrt totalworkinghours
plt.figure(figsize=(30,5))
sns.countplot(x='YearsInCurrentRole',hue='Attrition',data =rs)
plt.show()

# %% [markdown]
# #we can say that attrition rate is high if they are in current role for less amount of time

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
rs['Attrition'] = le.fit_transform(rs['Attrition'])

# %%
#checking the correlation of dataset
rscorr = rs.corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(rscorr,annot = True,linewidth = 0.5)

# %% [markdown]
# #we can see that all the columns are weakly correlated with Attrition.
# #there is higher correlation between Percent salary hike and Performance rating.
# #there is higher correlation between MonthlyIncome and Total working years, job level and Total working years.

# %%
#boxplots for checking outliers
collist =['Age','Attrition','DailyRate','DistanceFromHome','Education','HourlyRate','JobInvolvement','JobLevel','JobSatisfaction',
          'MonthlyIncome','MonthlyRate','PercentSalaryHike','PerformanceRating','StockOptionLevel','TotalWorkingYears',
         'TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion',
         'YearsWithCurrManager']

# %%
nrows = 15
ncols = 25

# %%
plt.figure(figsize = (35,130))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncols,i+1)
    sns.boxplot(rs[collist[i]],color = 'green',orient = 'v')
    plt.tight_layout()

# %%
rs.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %%
#there are skewness in some of the columns . we will have to remove the skewness.

# %% [markdown]
# #### preparing dataset for model training

# %%
x = rs.drop("Attrition",axis=1)

y= rs["Attrition"]

# %%
print(x.shape)
print(y.shape)
# Out:
# (1470, 31)
# (1470,)

# %%
#removing skewness
for index in x.skew().index:
    if x.skew().loc[index]>0.5:
        x[index]=np.log1p(x[index])
    if x.skew().loc[index]<-0.5:
        x[index]=np.square(x[index])

# %%
#we need to convert object columns to numeric using pd.get_dummies
x=pd.get_dummies(x,drop_first=True)

# %%
x.skew()
# Out:
# Age                                  0.413286
# DailyRate                           -0.003519
# DistanceFromHome                    -0.029121
# Education                           -0.289681
# EnvironmentSatisfaction             -0.321654
# HourlyRate                          -0.032311
# JobInvolvement                      -0.498419
# JobLevel                             0.448133
# JobSatisfaction                     -0.329672
# MonthlyIncome                        0.286448
# MonthlyRate                          0.018578
# NumCompaniesWorked                   0.092896
# PercentSalaryHike                    0.513543
# PerformanceRating                    1.921883
# RelationshipSatisfaction            -0.302828
# StockOptionLevel                     0.271963
# TotalWorkingYears                    0.322355
# TrainingTimesLastYear                0.492375
# WorkLifeBalance                      0.301318
# YearsAtCompany                      -0.207708
# ...

# %%
x
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      41       1102          0.693147          2                        2
# 1      49        279          2.197225          1                        3
# 2      37       1373          1.098612          2                        4
# 3      33       1392          1.386294          4                        4
# 4      27        591          1.098612          1                        1
# ...   ...        ...               ...        ...                      ...
# 1465   36        884          3.178054          2                        3
# 1466   39        613          1.945910          1                        4
# 1467   27        155          1.609438          3                        2
# 1468   49       1023          1.098612          3                        4
# 1469   34        628          2.197225          3                        2
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
scaledx = sc.fit_transform(x)

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int32

# %% [markdown]
# #### classifier model building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score

# %%
#we will make a function for model training
def max_aucroc_score(clf,scaledx,y):
    max_aucroc_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(scaledx, y,random_state = r_state,test_size=0.20,stratify=y)
        clf.fit(x_train,y_train)
        y_pred = clf.predict(x_test)
        aucroc_scr=roc_auc_score(y_test,y_pred)
        if aucroc_scr>max_aucroc_score:
            max_aucroc_score=aucroc_scr
            final_r_state=r_state
    print("max auc roc score corresponding to ",final_r_state," is ",max_aucroc_score)
    return final_r_state

# %%
lg=LogisticRegression()
max_aucroc_score(lg,scaledx,y)
# Out:
# max auc roc score corresponding to  43  is  0.783702299939702
# 43

# %%
#find the cross_val_score
from sklearn.model_selection import cross_val_score
print("Mean roc auc score for logistic classifier: ",cross_val_score(lg,scaledx,y,cv=5,scoring="roc_auc").mean())
print("standard deviation in roc auc score for logistic classifier: ",cross_val_score(lg,scaledx,y,cv=5,scoring="roc_auc").std())
print(cross_val_score(lg,scaledx,y,cv=5,scoring="roc_auc"))
# Out:
# Mean roc auc score for logistic classifier:  0.8425184815957902
# standard deviation in roc auc score for logistic classifier:  0.018609160244716556
# [0.84281843 0.84569783 0.83607546 0.81505728 0.87294341]

# %%
#For KNN we need to know the best value of k using grid search
from sklearn.model_selection import GridSearchCV
knn=KNeighborsClassifier()
neighbors={"n_neighbors":range(1,30)}
clf = GridSearchCV(knn, neighbors, cv=5,scoring="roc_auc")
clf.fit(scaledx,y)
clf.best_params_
# Out:
# {'n_neighbors': 28}

# %%
knn=KNeighborsClassifier(n_neighbors=28)
max_aucroc_score(knn,scaledx,y)
# Out:
# max auc roc score corresponding to  69  is  0.5531914893617021
# 69

# %%
print("Mean auc roc score for KNN classifier: ",cross_val_score(knn,scaledx,y,cv=5,scoring="roc_auc").mean())
print("standard deviation in auc roc score for KNN classifier: ",cross_val_score(knn,scaledx,y,cv=5,scoring="roc_auc").std())
print(cross_val_score(knn,scaledx,y,cv=5,scoring="roc_auc"))
# Out:
# Mean auc roc score for KNN classifier:  0.7526714997020114
# standard deviation in auc roc score for KNN classifier:  0.02204465330537351
# [0.74974593 0.73107215 0.76320096 0.73012318 0.78921526]

# %%
from sklearn.svm import SVC
svc=SVC()
parameters={"kernel":["linear", "poly", "rbf"],"C":[0.001,0.01,0.1,1,10]}
clf = GridSearchCV(svc, parameters, cv=5,scoring="roc_auc")
clf.fit(scaledx,y)
clf.best_params_
# Out:
# {'C': 0.1, 'kernel': 'linear'}

# %%
svc=SVC(kernel="linear",C=0.1)
max_aucroc_score(svc,scaledx,y)
# Out:
# max auc roc score corresponding to  80  is  0.8004134723059695
# 80

# %%
dtc=DecisionTreeClassifier()
max_aucroc_score(dtc,scaledx,y)
# Out:
# max auc roc score corresponding to  97  is  0.6935567232319751
# 97

# %%
print("Mean auc roc score for decision tree classifier: ",cross_val_score(dtc,scaledx,y,cv=5,scoring="roc_auc").mean())
print("standard deviation in auc roc score for decision tree classifier: ",cross_val_score(dtc,scaledx,y,cv=5,scoring="roc_auc").std())
print(cross_val_score(dtc,scaledx,y,cv=5,scoring="roc_auc"))
# Out:
# Mean auc roc score for decision tree classifier:  0.6303433233046689
# standard deviation in auc roc score for decision tree classifier:  0.01555919373650848
# [0.63897358 0.62068089 0.66521664 0.59328969 0.63735033]

# %%
from sklearn.ensemble import GradientBoostingClassifier
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500]}
gbc=GradientBoostingClassifier()
clf = GridSearchCV(gbc, parameters, cv=5,scoring="roc_auc")
clf.fit(scaledx,y)
clf.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 500}

# %%
gbc=GradientBoostingClassifier(learning_rate=0.01,n_estimators=500)
max_aucroc_score(gbc,scaledx,y)
# Out:
# max auc roc score corresponding to  48  is  0.6773193212162977
# 48

# %% [markdown]
# ###### #Lets choose SVC as our final model and random state 80

# %%
x_train, x_test, y_train, y_test = train_test_split(scaledx, y,random_state = 80,test_size=0.20)
svc=SVC(kernel="linear",C=0.1)
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)

# %%
print("accuracy score is : ",accuracy_score(y_test,y_pred))
print("classification report: \n",classification_report(y_test,y_pred))
print("AUC ROC Score: ",roc_auc_score(y_test,y_pred))
# Out:
# accuracy score is :  0.8979591836734694
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       247
#            1       0.87      0.43      0.57        47
#
#     accuracy                           0.90       294
#    macro avg       0.88      0.71      0.76       294
# weighted avg       0.90      0.90      0.88       294
#
# AUC ROC Score:  0.7066930829528814

# %%
#saving the SVC as best model
import joblib
joblib.dump(svc,"hr_anlytics.pkl")
# Out:
# ['hr_anlytics.pkl']
